# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy.stats import zscore
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Skyserver.csv')
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# finding:row 10000 and column 18

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %% [markdown]
# Findings:class column is object type remaining are int and float

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
df['rerun'].value_counts()
# Out:
# 301    10000
# Name: rerun, dtype: int64

# %%
#Because rerun has only one value so we will drop that column
df.drop('rerun',inplace=True,axis=1)

# %% [markdown]
# No null value in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   camcol     10000 non-null  int64
#  10  field      10000 non-null  int64
#  11  specobjid  10000 non-null  float64
#  12  class      10000 non-null  object
#  13  redshift   10000 non-null  float64
#  14  plate      10000 non-null  int64
#  15  mjd        10000 non-null  int64
#  16  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(6), object(1)
# memory usage: 1.3+ MB

# %%
sns.heatmap(df.isnull(),cbar=False)

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'camcol', 'field',
#        'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
le=LabelEncoder()
df['class']=le.fit_transform(df['class'])

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  camcol  field     specobjid  class  redshift  plate    mjd  \
# 0  15.22531  752       4    267  3.722360e+18      2 -0.000009   3306  54922
# 1  16.39150  752       4    267  3.638140e+17      2 -0.000055    323  51615
# 2  16.80125  752       4    268  3.232740e+17      0  0.123111    287  52023
# 3  15.90438  752       4    269  3.722370e+18      2 -0.000111   3306  54922
# 4  16.61326  752       4    269  3.722370e+18      2  0.000590   3306  54922
#
#    fiberid
# 0      491
# ...

# %% [markdown]
# # Summary statics

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run        camcol  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      16.840963     16.583579     16.422833    981.034800      3.648700
# ...

# %% [markdown]
# In plate,mjd,field,run mean is greater than median then these attribute data is right skewed
#
# Difference between 75% and max is high  ra,field,plate,fiberid

# %%
cor=df.corr()
cor
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# class     -3.355500e-15 -4.321896e-02 -5.891815e-02 -2.690437e-01
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(cor,annot=True)

# %% [markdown]
# specobjid,plate,mjd is highly correlated with class

# %%
sns.countplot(df['class'])

# %% [markdown]
# Star=5000
# Galaxy=900
# Quasar=4100

# %%
df['class'].plot.hist()

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['run'],hue=df['class'])

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['camcol'],hue=df['class'])

# %%
for i in df.columns:
    plt.figure(i)
    sns.scatterplot(x=df[i],y=df['class'])

# %% [markdown]
# Relation of all attribute with target attribute

# %%
lst=['ra','dec','field','plate','mjd','fiberid']
for i in lst:
    plt.figure(i)
    sns.boxplot(x=df[i])

# %%
df.skew()
# Out:
# objid        1.000150
# ra          -1.227350
# dec          1.191544
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# class        0.169292
# redshift     4.265729
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %%
sns.distplot(df['redshift'])

# %% [markdown]
# redshift is litte right skewed

# %% [markdown]
# # Removing Outliers

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[       nan, 0.16745842, 0.58492272, ..., 1.03148936, 1.30931064,
#         0.66863177],
#        [       nan, 0.16886159, 0.58311429, ..., 0.63621258, 0.87919741,
#         0.91101156],
#        [       nan, 0.17057433, 0.58347525, ..., 0.65633905, 0.60919097,
#         0.77527888],
#        ...,
#        [       nan, 0.92039468, 1.46090664, ..., 3.26608697, 2.69309363,
#         1.3036668 ],
#        [       nan, 0.92197294, 1.46432109, ..., 0.56688806, 0.70581092,
#         0.60143828],
#        [       nan, 0.91804124, 1.46639319, ..., 0.56688806, 0.70581092,
#         0.5820479 ]])

# %%
print(np.where(z>3))
# Out:
# (array([  45,  109,  129, ..., 9994, 9997, 9997], dtype=int64), array([13, 13, 13, ..., 14, 11, 14], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %% [markdown]
# # Model Training

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
print(x_train.shape,'\t',x_test.shape)
print(y_train.shape,'\t',y_test.shape)
# Out:
# (7500, 16) 	 (2500, 16)
# (7500,) 	 (2500,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
paramaters={'n_neighbors':range(22,25)}
kn=KNeighborsClassifier()
clf=GridSearchCV(kn,paramaters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'n_neighbors': 22}

# %%
le=LogisticRegression()
svc=SVC()
kn=KNeighborsClassifier(n_neighbors=22)

# %%
model=[le,svc,kn,DecisionTreeClassifier()]
for m in model:
    print(m)
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('Accuracy score',accuracy_score(y_test,pred))
    print('Confusion Metrix\n',confusion_matrix(y_test,pred))
    print('Classification report\n',classification_report(y_test,pred))
    print('***********************************************************************************')
    print('\n')
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Accuracy score 0.9712
# Confusion Metrix
#  [[1197    2   47]
#  [   9  233    0]
#  [  10    4  998]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1246
#            1       0.97      0.96      0.97       242
#            2       0.96      0.99      0.97      1012
#
#     accuracy                           0.97      2500
#    macro avg       0.97      0.97      0.97      2500
# weighted avg       0.97      0.97      0.97      2500
#
# ***********************************************************************************
#
#
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gc=GradientBoostingClassifier()
gc.fit(x_train,y_train)
pred=gc.predict(x_test)
print('Accuracy score',accuracy_score(y_test,pred))
print('Confusion Metrix\n',confusion_matrix(y_test,pred))
print('Classification report\n',classification_report(y_test,pred))
# Out:
# Accuracy score 0.9916
# Confusion Metrix
#  [[1235    8    3]
#  [   9  233    0]
#  [   0    1 1011]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1246
#            1       0.96      0.96      0.96       242
#            2       1.00      1.00      1.00      1012
#
#     accuracy                           0.99      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.99      0.99      0.99      2500

# %%
cm=confusion_matrix(y_test,pred)
sns.heatmap(cm,annot=True)

# %%
import joblib
joblib.dump(gc,'GC_SpaceServer.pkl')
# Out:
# ['GC_SpaceServer.pkl']
